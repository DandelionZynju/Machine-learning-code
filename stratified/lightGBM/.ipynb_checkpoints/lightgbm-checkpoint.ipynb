# %%
import os
import sys
import random
import functools
import numpy as np
import pandas as pd
import lightgbm as lgb
import optuna
from optuna.samplers import TPESampler
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import RepeatedKFold
import warnings
warnings.filterwarnings('ignore')

os.environ['PYTHONHASHSEED'] = '3407'
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"

SEED = 3407
random.seed(SEED)
np.random.seed(SEED)

def set_all_random_seeds(seed=3407):
    np.random.seed(seed)
    random.seed(seed)
    print(f"已设置随机种子为: {seed}")

def print_data_shapes(X_train, y_train, X_test, y_test):
    print(f"训练集形状: {X_train.shape}")
    print(f"测试集形状: {X_test.shape}")

def objective(trial, X_train, y_train, cv_folds, seed=3407):
 
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 10, 300),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 50),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 10),
        'random_state': seed,
        'n_jobs': 1,
        'verbosity': -1,
        'boosting_type': 'gbdt'
    }
    model = lgb.LGBMRegressor(**params)
    
    rkf = RepeatedKFold(n_splits=cv_folds, n_repeats=5, random_state=seed)
    cv_scores = cross_val_score(
        model, X_train, y_train,
        cv=rkf, scoring='neg_mean_squared_error',
        n_jobs=1
    )
    mse_scores = -cv_scores
    avg_mse = np.mean(mse_scores)
    mse_std = np.std(mse_scores)
    stability_penalty = 0.1 * mse_std / avg_mse if avg_mse > 0 else 0
    return avg_mse + stability_penalty

def optimize_hyperparameters(X_train, y_train, n_trials=100, cv_folds=10, seed=3407):
    print("开始Optuna超参数优化（LightGBM）...")

    sampler = TPESampler(
        seed=seed,
        n_startup_trials=10,
        group=False,
        warn_independent_sampling=False
    )

    study = optuna.create_study(
        direction='minimize',
        study_name=f'lightgbm_regression_seed{seed}',
        storage=None,
        load_if_exists=False,
        sampler=sampler,
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=10)
    )
    
    objective_partial = functools.partial(
        objective,
        X_train=X_train,
        y_train=y_train,
        cv_folds=cv_folds,
        seed=seed
    )
    
    study.optimize(objective_partial, n_trials=n_trials, n_jobs=1, show_progress_bar=True)
    
    best_params = study.best_params
    print(f"\n最佳超参数: {best_params}")
    print(f"最佳交叉验证MSE: {study.best_value:.4f}")
    
    best_params['random_state'] = seed
    return best_params, study

def train_best_model(X_train, y_train, best_params, seed=3407):
    final_params = best_params.copy()
    final_params.update({
        'random_state': seed,
        'n_jobs': 1,
        'verbosity': -1,
        'boosting_type': 'gbdt'
    })
    model = lgb.LGBMRegressor(**final_params)
    model.fit(
        X_train, y_train,
        eval_metric='mse',
    )
    return model, (X_train, y_train)

def evaluate_model(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)
    train_mae = mean_absolute_error(y_train, y_train_pred)
    test_mae = mean_absolute_error(y_test, y_test_pred)
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    
    mse_diff = abs(train_mse - test_mse) / train_mse * 100 if train_mse > 0 else 0
    r2_diff = abs(train_r2 - test_r2) * 100
    
    print("\n" + "="*50)
    print("模型性能评估")
    print("="*50)
    print(f"{'指标':<15} {'训练集':<15} {'测试集':<15} {'差异(%)':<10}")
    print("-"*50)
    print(f"{'MSE':<15} {train_mse:<15.4f} {test_mse:<15.4f} {mse_diff:<10.2f}")
    print(f"{'RMSE':<15} {np.sqrt(train_mse):<15.4f} {np.sqrt(test_mse):<15.4f} {'-':<10}")
    print(f"{'MAE':<15} {train_mae:<15.4f} {test_mae:<15.4f} {'-':<10}")
    print(f"{'R²':<15} {train_r2:<15.4f} {test_r2:<15.4f} {r2_diff:<10.2f}")
    print("="*50)
    
    metrics_dict = {
        'train_mse': train_mse, 'test_mse': test_mse,
        'train_mae': train_mae, 'test_mae': test_mae,
        'train_r2': train_r2, 'test_r2': test_r2,
        'mse_diff_percent': mse_diff, 'r2_diff_percent': r2_diff
    }
    predictions = {'y_train_pred': y_train_pred, 'y_test_pred': y_test_pred}
    return metrics_dict, predictions

def save_model(model, filepath='best_lightgbm_model.pkl'):
    import joblib
    joblib.dump(model, filepath)
    print(f"模型已保存到: {filepath}")

def lightgbm_optimization_pipeline(X_train, y_train, X_test, y_test, n_trials=100, cv_folds=5, seed=3407):
    set_all_random_seeds(seed)
    print_data_shapes(X_train, y_train, X_test, y_test)
    
    best_params, study = optimize_hyperparameters(
        X_train, y_train, n_trials, cv_folds, seed
    )
    model, train_data = train_best_model(X_train, y_train, best_params, seed)
    metrics, predictions = evaluate_model(model, X_train, y_train, X_test, y_test)
    save_model(model, 'LightGBM_regression_model.pkl')
    print("\n优化完成！")
    return model, best_params, metrics, study, predictions, train_data

def main():
    SEED = 36
    
    X_train = pd.read_csv("data_train_x.csv")
    X_test  = pd.read_csv("data_test_x.csv")
    y_train = pd.read_csv("data_train_y.csv")
    y_test  = pd.read_csv("data_test_y.csv")
    
    if len(y_train.shape) > 1 and y_train.shape[1] == 1:
        y_train = y_train.iloc[:, 0]
    if len(y_test.shape) > 1 and y_test.shape[1] == 1:
        y_test = y_test.iloc[:, 0]
    
    model, best_params, metrics, study, predictions, train_data = lightgbm_optimization_pipeline(
        X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test,
        n_trials=100,
        cv_folds=10,
        seed=SEED
    )
    
    print(f"\n最佳参数数量: {len(best_params)}")
    print(f"训练集R²: {metrics['train_r2']:.4f}")
    print(f"测试集R²: {metrics['test_r2']:.4f}")
    
    results = {
        'model': model, 'best_params': best_params, 'metrics': metrics,
        'study': study, 'predictions': predictions, 'train_data': train_data
    }
    return results

if __name__ == "__main__":
    results = main()
# Out:
# [I 2026-04-10 10:32:04,002] A new study created in memory with name: lightgbm_regression_seed36
# 已设置随机种子为: 36
# 训练集形状: (918, 30)
# 测试集形状: (234, 30)
# 开始Optuna超参数优化（LightGBM）...
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-04-10 10:32:21,873] Trial 0 finished with value: 15.92870610979866 and parameters: {'n_estimators': 756, 'max_depth': 9, 'learning_rate': 0.25496836683723545, 'num_leaves': 51, 'subsample': 0.9036795649350824, 'colsample_bytree': 0.6816072982605145, 'min_child_samples': 13, 'reg_alpha': 2.1496172800756097e-06, 'reg_lambda': 0.004654371916908341, 'subsample_freq': 1}. Best is trial 0 with value: 15.92870610979866.
# [I 2026-04-10 10:32:38,645] Trial 1 finished with value: 12.78378317949212 and parameters: {'n_estimators': 953, 'max_depth': 12, 'learning_rate': 0.06495445538193606, 'num_leaves': 67, 'subsample': 0.6160164157483632, 'colsample_bytree': 0.5011829875221057, 'min_child_samples': 15, 'reg_alpha': 2.38830142627334e-05, 'reg_lambda': 0.00011876633315381987, 'subsample_freq': 3}. Best is trial 1 with value: 12.78378317949212.
# [I 2026-04-10 10:32:44,698] Trial 2 finished with value: 12.21927955107319 and parameters: {'n_estimators': 514, 'max_depth': 5, 'learning_rate': 0.09794544066437282, 'num_leaves': 141, 'subsample': 0.7963423978321704, 'colsample_bytree': 0.6635060437422827, 'min_child_samples': 15, 'reg_alpha': 8.720919622825697e-07, 'reg_lambda': 3.508839507142846e-07, 'subsample_freq': 1}. Best is trial 2 with value: 12.21927955107319.
# [I 2026-04-10 10:32:50,362] Trial 3 finished with value: 14.316564724147801 and parameters: {'n_estimators': 666, 'max_depth': 8, 'learning_rate': 0.022883347201742434, 'num_leaves': 162, 'subsample': 0.5871138276751828, 'colsample_bytree': 0.6709678761677094, 'min_child_samples': 50, 'reg_alpha': 1.235754197443211e-06, 'reg_lambda': 1.6933701745607335e-08, 'subsample_freq': 2}. Best is trial 2 with value: 12.21927955107319.
# [I 2026-04-10 10:32:56,024] Trial 4 finished with value: 11.966777149328125 and parameters: {'n_estimators': 535, 'max_depth': 6, 'learning_rate': 0.08810828194527495, 'num_leaves': 132, 'subsample': 0.5935048690546175, 'colsample_bytree': 0.6758823282652969, 'min_child_samples': 27, 'reg_alpha': 0.16522802388450342, 'reg_lambda': 4.2209828173229886e-05, 'subsample_freq': 5}. Best is trial 4 with value: 11.966777149328125.
# [I 2026-04-10 10:33:03,792] Trial 5 finished with value: 12.565770990143799 and parameters: {'n_estimators': 886, 'max_depth': 4, 'learning_rate': 0.11642943630265588, 'num_leaves': 207, 'subsample': 0.6027116794112948, 'colsample_bytree': 0.5415063361356489, 'min_child_samples': 14, 'reg_alpha': 0.6600812359654714, 'reg_lambda': 0.028350503307304414, 'subsample_freq': 7}. Best is trial 4 with value: 11.966777149328125.
# [I 2026-04-10 10:33:07,578] Trial 6 finished with value: 13.976043631397978 and parameters: {'n_estimators': 460, 'max_depth': 3, 'learning_rate': 0.021931761367163547, 'num_leaves': 68, 'subsample': 0.5810599576133326, 'colsample_bytree': 0.9735675893055891, 'min_child_samples': 16, 'reg_alpha': 1.3355851070249456, 'reg_lambda': 0.08702728880976303, 'subsample_freq': 2}. Best is trial 4 with value: 11.966777149328125.
# [I 2026-04-10 10:33:13,869] Trial 7 finished with value: 12.494015154360214 and parameters: {'n_estimators': 896, 'max_depth': 3, 'learning_rate': 0.09559988588732271, 'num_leaves': 193, 'subsample': 0.6591082985842283, 'colsample_bytree': 0.7253576135922132, 'min_child_samples': 41, 'reg_alpha': 0.6633281729091454, 'reg_lambda': 0.025741123995833098, 'subsample_freq': 5}. Best is trial 4 with value: 11.966777149328125.
# [I 2026-04-10 10:33:32,856] Trial 8 finished with value: 11.975596875750995 and parameters: {'n_estimators': 971, 'max_depth': 6, 'learning_rate': 0.02504938343836337, 'num_leaves': 173, 'subsample': 0.9966357452265957, 'colsample_bytree': 0.9451198332868651, 'min_child_samples': 10, 'reg_alpha': 2.947468431309246e-05, 'reg_lambda': 6.541385493631252e-05, 'subsample_freq': 2}. Best is trial 4 with value: 11.966777149328125.
# [I 2026-04-10 10:33:34,612] Trial 9 finished with value: 11.648309224653664 and parameters: {'n_estimators': 110, 'max_depth': 10, 'learning_rate': 0.25409494447930586, 'num_leaves': 84, 'subsample': 0.9803072856975419, 'colsample_bytree': 0.8869022701608178, 'min_child_samples': 43, 'reg_alpha': 0.00025973333897255543, 'reg_lambda': 2.747930143219272, 'subsample_freq': 4}. Best is trial 9 with value: 11.648309224653664.
# [I 2026-04-10 10:33:36,389] Trial 10 finished with value: 11.969019292740121 and parameters: {'n_estimators': 112, 'max_depth': 11, 'learning_rate': 0.26307673135421294, 'num_leaves': 291, 'subsample': 0.7934603504867396, 'colsample_bytree': 0.8545834921820848, 'min_child_samples': 35, 'reg_alpha': 1.0365298730694351e-08, 'reg_lambda': 5.88125765150998, 'subsample_freq': 9}. Best is trial 9 with value: 11.648309224653664.
# [I 2026-04-10 10:33:38,444] Trial 11 finished with value: 12.123951923681668 and parameters: {'n_estimators': 171, 'max_depth': 10, 'learning_rate': 0.1638915690067319, 'num_leaves': 106, 'subsample': 0.515080870079759, 'colsample_bytree': 0.837471412295771, 'min_child_samples': 26, 'reg_alpha': 0.008996506379389035, 'reg_lambda': 4.402622790023293e-06, 'subsample_freq': 5}. Best is trial 9 with value: 11.648309224653664.
# [I 2026-04-10 10:33:43,044] Trial 12 finished with value: 11.472901553815205 and parameters: {'n_estimators': 350, 'max_depth': 7, 'learning_rate': 0.04678005464034199, 'num_leaves': 119, 'subsample': 0.7440780342922266, 'colsample_bytree': 0.8160036519679663, 'min_child_samples': 27, 'reg_alpha': 0.005828635846939763, 'reg_lambda': 9.715737442686603, 'subsample_freq': 7}. Best is trial 12 with value: 11.472901553815205.
# [I 2026-04-10 10:33:46,513] Trial 13 finished with value: 12.1175435633128 and parameters: {'n_estimators': 299, 'max_depth': 8, 'learning_rate': 0.0415373502394592, 'num_leaves': 25, 'subsample': 0.7327820378667549, 'colsample_bytree': 0.8313852694038466, 'min_child_samples': 35, 'reg_alpha': 0.004550986455998549, 'reg_lambda': 9.431876459622863, 'subsample_freq': 7}. Best is trial 12 with value: 11.472901553815205.
# [I 2026-04-10 10:33:50,257] Trial 14 finished with value: 15.994931064882596 and parameters: {'n_estimators': 318, 'max_depth': 10, 'learning_rate': 0.012407466053641954, 'num_leaves': 100, 'subsample': 0.8825175090400681, 'colsample_bytree': 0.8963827509413708, 'min_child_samples': 50, 'reg_alpha': 0.005744272582845584, 'reg_lambda': 0.6772994266400435, 'subsample_freq': 10}. Best is trial 12 with value: 11.472901553815205.
# [I 2026-04-10 10:33:53,874] Trial 15 finished with value: 11.379398545128435 and parameters: {'n_estimators': 291, 'max_depth': 7, 'learning_rate': 0.04325264839167038, 'num_leaves': 14, 'subsample': 0.7145682381997135, 'colsample_bytree': 0.7812052722759213, 'min_child_samples': 21, 'reg_alpha': 0.0003867407230585892, 'reg_lambda': 0.4474297971710215, 'subsample_freq': 7}. Best is trial 15 with value: 11.379398545128435.
# [I 2026-04-10 10:33:58,110] Trial 16 finished with value: 11.539473320425879 and parameters: {'n_estimators': 310, 'max_depth': 7, 'learning_rate': 0.04068596878088835, 'num_leaves': 21, 'subsample': 0.7375380494558933, 'colsample_bytree': 0.7675540250912836, 'min_child_samples': 24, 'reg_alpha': 0.031699967880065974, 'reg_lambda': 0.3046318953797137, 'subsample_freq': 7}. Best is trial 15 with value: 11.379398545128435.
# [I 2026-04-10 10:34:09,679] Trial 17 finished with value: 12.271260154694232 and parameters: {'n_estimators': 406, 'max_depth': 7, 'learning_rate': 0.04668600390158921, 'num_leaves': 262, 'subsample': 0.6819221817018289, 'colsample_bytree': 0.7726150622483818, 'min_child_samples': 5, 'reg_alpha': 0.0004209028931524139, 'reg_lambda': 0.0010812778978570275, 'subsample_freq': 8}. Best is trial 15 with value: 11.379398545128435.
# [I 2026-04-10 10:34:17,248] Trial 18 finished with value: 12.14771684575354 and parameters: {'n_estimators': 648, 'max_depth': 5, 'learning_rate': 0.013722145676051716, 'num_leaves': 237, 'subsample': 0.8201768817207898, 'colsample_bytree': 0.5949099904699454, 'min_child_samples': 22, 'reg_alpha': 0.00048199069746615776, 'reg_lambda': 0.6067036473919704, 'subsample_freq': 6}. Best is trial 15 with value: 11.379398545128435.
# [I 2026-04-10 10:34:19,616] Trial 19 finished with value: 13.421452313593848 and parameters: {'n_estimators': 209, 'max_depth': 6, 'learning_rate': 0.0306362033827789, 'num_leaves': 114, 'subsample': 0.6820766446164885, 'colsample_bytree': 0.7804965819577945, 'min_child_samples': 31, 'reg_alpha': 5.742745706074467, 'reg_lambda': 0.002654724445199402, 'subsample_freq': 9}. Best is trial 15 with value: 11.379398545128435.
# [I 2026-04-10 10:34:24,360] Trial 20 finished with value: 11.358272008408157 and parameters: {'n_estimators': 393, 'max_depth': 9, 'learning_rate': 0.06035585430513802, 'num_leaves': 13, 'subsample': 0.8596476852688493, 'colsample_bytree': 0.7259481774575013, 'min_child_samples': 19, 'reg_alpha': 4.337903258401849e-05, 'reg_lambda': 0.11619675009944885, 'subsample_freq': 8}. Best is trial 20 with value: 11.358272008408157.
# [I 2026-04-10 10:34:29,757] Trial 21 finished with value: 11.620117005291782 and parameters: {'n_estimators': 382, 'max_depth': 9, 'learning_rate': 0.06725288107681578, 'num_leaves': 17, 'subsample': 0.8308602871928219, 'colsample_bytree': 0.7261039107824795, 'min_child_samples': 20, 'reg_alpha': 2.4946567188737866e-05, 'reg_lambda': 0.12227165418335263, 'subsample_freq': 8}. Best is trial 20 with value: 11.358272008408157.
# [I 2026-04-10 10:34:33,857] Trial 22 finished with value: 11.243663393021992 and parameters: {'n_estimators': 230, 'max_depth': 8, 'learning_rate': 0.032726636124712084, 'num_leaves': 45, 'subsample': 0.8942115431279183, 'colsample_bytree': 0.8120316225860419, 'min_child_samples': 20, 'reg_alpha': 0.0012315576486529051, 'reg_lambda': 1.447077584827582, 'subsample_freq': 6}. Best is trial 22 with value: 11.243663393021992.
# [I 2026-04-10 10:34:38,360] Trial 23 finished with value: 12.051828012858033 and parameters: {'n_estimators': 241, 'max_depth': 9, 'learning_rate': 0.017664201400113842, 'num_leaves': 51, 'subsample': 0.8979014191299866, 'colsample_bytree': 0.6158290485814164, 'min_child_samples': 19, 'reg_alpha': 0.00012044479730447835, 'reg_lambda': 0.011713317705706203, 'subsample_freq': 6}. Best is trial 22 with value: 11.243663393021992.
# [I 2026-04-10 10:34:42,831] Trial 24 finished with value: 11.240457259021662 and parameters: {'n_estimators': 241, 'max_depth': 8, 'learning_rate': 0.03419972022337806, 'num_leaves': 44, 'subsample': 0.9479075662538928, 'colsample_bytree': 0.8016940951795493, 'min_child_samples': 19, 'reg_alpha': 0.0016236098990106544, 'reg_lambda': 1.2024141715736891, 'subsample_freq': 8}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:34:54,315] Trial 25 finished with value: 11.663943347686518 and parameters: {'n_estimators': 433, 'max_depth': 8, 'learning_rate': 0.0339289689358338, 'num_leaves': 43, 'subsample': 0.940143252086014, 'colsample_bytree': 0.7259849693504435, 'min_child_samples': 9, 'reg_alpha': 0.04867817823697559, 'reg_lambda': 1.7326039001069913, 'subsample_freq': 10}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:34:57,653] Trial 26 finished with value: 11.473304292225956 and parameters: {'n_estimators': 220, 'max_depth': 9, 'learning_rate': 0.06296157477809249, 'num_leaves': 82, 'subsample': 0.8629593054295029, 'colsample_bytree': 0.8793200959115497, 'min_child_samples': 32, 'reg_alpha': 0.001061542212833444, 'reg_lambda': 0.08178094600492627, 'subsample_freq': 8}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:35:01,574] Trial 27 finished with value: 11.453899138897375 and parameters: {'n_estimators': 165, 'max_depth': 11, 'learning_rate': 0.031820436909472394, 'num_leaves': 41, 'subsample': 0.9459490289133664, 'colsample_bytree': 0.9240554168837095, 'min_child_samples': 18, 'reg_alpha': 7.3841141493432564e-06, 'reg_lambda': 0.0004139876885315998, 'subsample_freq': 9}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:35:14,326] Trial 28 finished with value: 12.434167481077049 and parameters: {'n_estimators': 480, 'max_depth': 8, 'learning_rate': 0.05598309517117647, 'num_leaves': 68, 'subsample': 0.9352321828030287, 'colsample_bytree': 0.8137353909659673, 'min_child_samples': 10, 'reg_alpha': 1.49184993716124e-08, 'reg_lambda': 1.515612499662453, 'subsample_freq': 6}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:35:25,546] Trial 29 finished with value: 11.242463221770983 and parameters: {'n_estimators': 610, 'max_depth': 10, 'learning_rate': 0.018131812569905835, 'num_leaves': 47, 'subsample': 0.8570554498630556, 'colsample_bytree': 0.7094978312892788, 'min_child_samples': 24, 'reg_alpha': 1.8948116791845066e-07, 'reg_lambda': 0.006858971002630366, 'subsample_freq': 8}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:35:37,366] Trial 30 finished with value: 11.308229517771181 and parameters: {'n_estimators': 608, 'max_depth': 11, 'learning_rate': 0.017160762824904523, 'num_leaves': 46, 'subsample': 0.9147477309727388, 'colsample_bytree': 0.609386781852307, 'min_child_samples': 23, 'reg_alpha': 1.2731528144333502e-07, 'reg_lambda': 0.0025761319791318535, 'subsample_freq': 4}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:35:49,454] Trial 31 finished with value: 11.642143318875359 and parameters: {'n_estimators': 604, 'max_depth': 12, 'learning_rate': 0.010342633117682475, 'num_leaves': 47, 'subsample': 0.9200342276202047, 'colsample_bytree': 0.6290504543351452, 'min_child_samples': 23, 'reg_alpha': 1.1372331606439438e-07, 'reg_lambda': 0.007025113061669283, 'subsample_freq': 4}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:36:02,785] Trial 32 finished with value: 11.406530750851905 and parameters: {'n_estimators': 792, 'max_depth': 11, 'learning_rate': 0.016656368152927335, 'num_leaves': 93, 'subsample': 0.9702250891694728, 'colsample_bytree': 0.5728139403504747, 'min_child_samples': 30, 'reg_alpha': 1.676640527738523e-07, 'reg_lambda': 0.0010646902413513175, 'subsample_freq': 4}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:36:18,118] Trial 33 finished with value: 11.283134501574564 and parameters: {'n_estimators': 735, 'max_depth': 10, 'learning_rate': 0.017621319571725063, 'num_leaves': 65, 'subsample': 0.8968074194366602, 'colsample_bytree': 0.5119436156285335, 'min_child_samples': 17, 'reg_alpha': 2.9379909461003995e-07, 'reg_lambda': 3.939103249486343e-06, 'subsample_freq': 4}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:36:33,263] Trial 34 finished with value: 11.558752096789107 and parameters: {'n_estimators': 744, 'max_depth': 10, 'learning_rate': 0.026594830663477016, 'num_leaves': 66, 'subsample': 0.868875337973485, 'colsample_bytree': 0.5005976150436167, 'min_child_samples': 17, 'reg_alpha': 5.451976830534993e-06, 'reg_lambda': 8.12804638936713e-06, 'subsample_freq': 3}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:36:50,065] Trial 35 finished with value: 11.321010770584532 and parameters: {'n_estimators': 748, 'max_depth': 10, 'learning_rate': 0.019088235171799008, 'num_leaves': 65, 'subsample': 0.7901281018338987, 'colsample_bytree': 0.5376275089193643, 'min_child_samples': 14, 'reg_alpha': 7.620225206439016e-07, 'reg_lambda': 1.000224019845265e-07, 'subsample_freq': 3}. Best is trial 24 with value: 11.240457259021662.
# [I 2026-04-10 10:37:06,964] Trial 36 finished with value: 11.096222165547776 and parameters: {'n_estimators': 699, 'max_depth': 9, 'learning_rate': 0.013177840617295943, 'num_leaves': 35, 'subsample': 0.8308524733821403, 'colsample_bytree': 0.6482357935097649, 'min_child_samples': 12, 'reg_alpha': 0.0020504019840706556, 'reg_lambda': 1.208478960950479e-06, 'subsample_freq': 6}. Best is trial 36 with value: 11.096222165547776.
# [I 2026-04-10 10:37:27,657] Trial 37 finished with value: 10.992708005735912 and parameters: {'n_estimators': 569, 'max_depth': 9, 'learning_rate': 0.011493815742049829, 'num_leaves': 142, 'subsample': 0.8354042633509751, 'colsample_bytree': 0.6547862154507571, 'min_child_samples': 7, 'reg_alpha': 0.0020694403146063823, 'reg_lambda': 3.1724379087757477e-07, 'subsample_freq': 6}. Best is trial 37 with value: 10.992708005735912.
# [I 2026-04-10 10:37:51,005] Trial 38 finished with value: 10.983670477862923 and parameters: {'n_estimators': 577, 'max_depth': 9, 'learning_rate': 0.010396325400189753, 'num_leaves': 164, 'subsample': 0.7753830064619311, 'colsample_bytree': 0.6947536287893756, 'min_child_samples': 5, 'reg_alpha': 0.04631637957534537, 'reg_lambda': 6.152358547481869e-07, 'subsample_freq': 9}. Best is trial 38 with value: 10.983670477862923.
# [I 2026-04-10 10:38:12,347] Trial 39 finished with value: 10.910244738454358 and parameters: {'n_estimators': 533, 'max_depth': 9, 'learning_rate': 0.010566222756878433, 'num_leaves': 145, 'subsample': 0.7705827954726557, 'colsample_bytree': 0.6537059846652583, 'min_child_samples': 5, 'reg_alpha': 0.04903710814480872, 'reg_lambda': 4.5438620669323626e-07, 'subsample_freq': 9}. Best is trial 39 with value: 10.910244738454358.
# [I 2026-04-10 10:38:33,605] Trial 40 finished with value: 10.86727474224785 and parameters: {'n_estimators': 536, 'max_depth': 9, 'learning_rate': 0.010053581801940306, 'num_leaves': 145, 'subsample': 0.7786500219697181, 'colsample_bytree': 0.656103958569128, 'min_child_samples': 5, 'reg_alpha': 0.078874781234035, 'reg_lambda': 4.05928942543089e-07, 'subsample_freq': 10}. Best is trial 40 with value: 10.86727474224785.
# [I 2026-04-10 10:38:55,025] Trial 41 finished with value: 10.938175053501972 and parameters: {'n_estimators': 556, 'max_depth': 9, 'learning_rate': 0.010081138582851507, 'num_leaves': 147, 'subsample': 0.7856646743994904, 'colsample_bytree': 0.6450455460058407, 'min_child_samples': 5, 'reg_alpha': 0.15004849850265298, 'reg_lambda': 3.969991707308673e-07, 'subsample_freq': 10}. Best is trial 40 with value: 10.86727474224785.
# [I 2026-04-10 10:39:15,627] Trial 42 finished with value: 10.924604035693955 and parameters: {'n_estimators': 527, 'max_depth': 9, 'learning_rate': 0.0101455038593241, 'num_leaves': 147, 'subsample': 0.775829931033065, 'colsample_bytree': 0.6940049638465646, 'min_child_samples': 5, 'reg_alpha': 0.1709395900420062, 'reg_lambda': 1.6609239583498683e-08, 'subsample_freq': 10}. Best is trial 40 with value: 10.86727474224785.
# [I 2026-04-10 10:39:35,554] Trial 43 finished with value: 10.856581423505322 and parameters: {'n_estimators': 518, 'max_depth': 9, 'learning_rate': 0.010029877845067226, 'num_leaves': 169, 'subsample': 0.7640494982171174, 'colsample_bytree': 0.6776920248953655, 'min_child_samples': 5, 'reg_alpha': 0.18699703409242607, 'reg_lambda': 5.0752739261243434e-08, 'subsample_freq': 10}. Best is trial 43 with value: 10.856581423505322.
# [I 2026-04-10 10:39:51,943] Trial 44 finished with value: 10.997611552063583 and parameters: {'n_estimators': 518, 'max_depth': 9, 'learning_rate': 0.0143450967075806, 'num_leaves': 182, 'subsample': 0.7741559568564026, 'colsample_bytree': 0.6927065619775895, 'min_child_samples': 8, 'reg_alpha': 0.1434438421398214, 'reg_lambda': 1.8343929618603202e-08, 'subsample_freq': 10}. Best is trial 43 with value: 10.856581423505322.
# [I 2026-04-10 10:40:02,537] Trial 45 finished with value: 11.239626495915205 and parameters: {'n_estimators': 491, 'max_depth': 8, 'learning_rate': 0.01017648837544427, 'num_leaves': 148, 'subsample': 0.7651937468684159, 'colsample_bytree': 0.6639902810343317, 'min_child_samples': 12, 'reg_alpha': 1.8999642122303937, 'reg_lambda': 7.192744219612539e-08, 'subsample_freq': 10}. Best is trial 43 with value: 10.856581423505322.
# [I 2026-04-10 10:40:21,762] Trial 46 finished with value: 11.105797016303054 and parameters: {'n_estimators': 540, 'max_depth': 12, 'learning_rate': 0.014893376355983286, 'num_leaves': 204, 'subsample': 0.710202744282584, 'colsample_bytree': 0.6400441730729614, 'min_child_samples': 7, 'reg_alpha': 0.2523823192757111, 'reg_lambda': 1.1570048758603047e-08, 'subsample_freq': 10}. Best is trial 43 with value: 10.856581423505322.
# [I 2026-04-10 10:40:37,767] Trial 47 finished with value: 10.837537396989418 and parameters: {'n_estimators': 449, 'max_depth': 10, 'learning_rate': 0.01160578516673828, 'num_leaves': 128, 'subsample': 0.6379141687402075, 'colsample_bytree': 0.6778202871820942, 'min_child_samples': 5, 'reg_alpha': 0.3628980021848823, 'reg_lambda': 5.679568077119734e-08, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:40:48,404] Trial 48 finished with value: 11.080257741781264 and parameters: {'n_estimators': 445, 'max_depth': 11, 'learning_rate': 0.021323170500180767, 'num_leaves': 126, 'subsample': 0.6337168798617449, 'colsample_bytree': 0.6819825769318082, 'min_child_samples': 11, 'reg_alpha': 0.45170503819563457, 'reg_lambda': 4.630478007976287e-08, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:41:01,701] Trial 49 finished with value: 11.083834396572138 and parameters: {'n_estimators': 655, 'max_depth': 10, 'learning_rate': 0.011942852173644934, 'num_leaves': 167, 'subsample': 0.7160456248064496, 'colsample_bytree': 0.5818220234392208, 'min_child_samples': 7, 'reg_alpha': 9.05237291591305, 'reg_lambda': 1.438718151016948e-07, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:41:16,464] Trial 50 finished with value: 10.910985348467959 and parameters: {'n_estimators': 505, 'max_depth': 10, 'learning_rate': 0.015006787300958698, 'num_leaves': 181, 'subsample': 0.8137452890034925, 'colsample_bytree': 0.7504625528302691, 'min_child_samples': 9, 'reg_alpha': 1.9986803436124074, 'reg_lambda': 3.062619683836638e-08, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:41:30,484] Trial 51 finished with value: 10.864386380088613 and parameters: {'n_estimators': 493, 'max_depth': 10, 'learning_rate': 0.012037375640749831, 'num_leaves': 189, 'subsample': 0.809844691790696, 'colsample_bytree': 0.7048030855295867, 'min_child_samples': 9, 'reg_alpha': 1.7804015558783002, 'reg_lambda': 2.5383827797491878e-08, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:41:41,382] Trial 52 finished with value: 10.993937091888663 and parameters: {'n_estimators': 483, 'max_depth': 10, 'learning_rate': 0.014643628794403342, 'num_leaves': 181, 'subsample': 0.557932785365674, 'colsample_bytree': 0.7490499353892235, 'min_child_samples': 9, 'reg_alpha': 2.0005276328869126, 'reg_lambda': 3.372447515740449e-08, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:41:49,346] Trial 53 finished with value: 11.236151250701491 and parameters: {'n_estimators': 424, 'max_depth': 11, 'learning_rate': 0.012013359246206003, 'num_leaves': 225, 'subsample': 0.8084250349564478, 'colsample_bytree': 0.7514520261996871, 'min_child_samples': 15, 'reg_alpha': 3.220549846121892, 'reg_lambda': 1.9895118987337609e-07, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:42:04,079] Trial 54 finished with value: 10.917119411277572 and parameters: {'n_estimators': 459, 'max_depth': 10, 'learning_rate': 0.01510388033000403, 'num_leaves': 131, 'subsample': 0.7580367409632521, 'colsample_bytree': 0.6710618375894243, 'min_child_samples': 7, 'reg_alpha': 0.9046130668069453, 'reg_lambda': 1.1470648734366389e-06, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:42:14,369] Trial 55 finished with value: 11.175955235664366 and parameters: {'n_estimators': 358, 'max_depth': 11, 'learning_rate': 0.012312263657402829, 'num_leaves': 195, 'subsample': 0.8101139851609372, 'colsample_bytree': 0.7455699840556912, 'min_child_samples': 13, 'reg_alpha': 0.017340188114755826, 'reg_lambda': 3.0937548049423886e-08, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:42:28,015] Trial 56 finished with value: 14.437602320307722 and parameters: {'n_estimators': 504, 'max_depth': 10, 'learning_rate': 0.14079223587475, 'num_leaves': 226, 'subsample': 0.6874181185924682, 'colsample_bytree': 0.7076824227824142, 'min_child_samples': 10, 'reg_alpha': 0.39399577784256085, 'reg_lambda': 1.956585094863655e-05, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:42:50,899] Trial 57 finished with value: 11.699958914147821 and parameters: {'n_estimators': 587, 'max_depth': 11, 'learning_rate': 0.020237126254324476, 'num_leaves': 186, 'subsample': 0.7422440378380755, 'colsample_bytree': 0.6155749621634818, 'min_child_samples': 6, 'reg_alpha': 0.09024907801027547, 'reg_lambda': 7.16306443771836e-08, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:42:54,426] Trial 58 finished with value: 12.253172197374225 and parameters: {'n_estimators': 351, 'max_depth': 4, 'learning_rate': 0.02436093120426905, 'num_leaves': 157, 'subsample': 0.5549285140179346, 'colsample_bytree': 0.7114532600979078, 'min_child_samples': 9, 'reg_alpha': 0.013602582646968526, 'reg_lambda': 1.1919123003287904e-06, 'subsample_freq': 8}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:43:00,153] Trial 59 finished with value: 14.496683242490258 and parameters: {'n_estimators': 538, 'max_depth': 8, 'learning_rate': 0.011504742392232372, 'num_leaves': 169, 'subsample': 0.7257456964111827, 'colsample_bytree': 0.673452651335551, 'min_child_samples': 41, 'reg_alpha': 0.8629743487909188, 'reg_lambda': 1.8603623663032809e-07, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:43:13,177] Trial 60 finished with value: 10.988783354482026 and parameters: {'n_estimators': 633, 'max_depth': 12, 'learning_rate': 0.013166133432344173, 'num_leaves': 114, 'subsample': 0.6477946557706143, 'colsample_bytree': 0.630088913967131, 'min_child_samples': 11, 'reg_alpha': 3.2583465090981045, 'reg_lambda': 3.3462603905305557e-06, 'subsample_freq': 8}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:43:28,398] Trial 61 finished with value: 11.003485328483487 and parameters: {'n_estimators': 465, 'max_depth': 10, 'learning_rate': 0.015915464364912035, 'num_leaves': 129, 'subsample': 0.7582533788049892, 'colsample_bytree': 0.669879796145594, 'min_child_samples': 7, 'reg_alpha': 0.6674613951421218, 'reg_lambda': 6.606156844643034e-07, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:43:42,259] Trial 62 finished with value: 10.910213627144836 and parameters: {'n_estimators': 456, 'max_depth': 10, 'learning_rate': 0.013537391138555316, 'num_leaves': 159, 'subsample': 0.8018926408111928, 'colsample_bytree': 0.6807911491395456, 'min_child_samples': 8, 'reg_alpha': 1.2909281298692683, 'reg_lambda': 1.7290225902904202e-06, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:43:54,962] Trial 63 finished with value: 10.844220562889973 and parameters: {'n_estimators': 412, 'max_depth': 9, 'learning_rate': 0.013329918750908358, 'num_leaves': 177, 'subsample': 0.8059324427532661, 'colsample_bytree': 0.7355493235173293, 'min_child_samples': 9, 'reg_alpha': 0.08400347743032249, 'reg_lambda': 4.455249739783766e-08, 'subsample_freq': 1}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:44:13,178] Trial 64 finished with value: 10.889076230680056 and parameters: {'n_estimators': 416, 'max_depth': 9, 'learning_rate': 0.011246092253874298, 'num_leaves': 157, 'subsample': 0.8452857832167767, 'colsample_bytree': 0.7322024899255244, 'min_child_samples': 5, 'reg_alpha': 0.06988701832831165, 'reg_lambda': 5.545251221933991e-08, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:44:23,708] Trial 65 finished with value: 10.959890665770873 and parameters: {'n_estimators': 405, 'max_depth': 7, 'learning_rate': 0.01335047101374108, 'num_leaves': 156, 'subsample': 0.8357944492811862, 'colsample_bytree': 0.7288695966009348, 'min_child_samples': 8, 'reg_alpha': 0.27963181540894244, 'reg_lambda': 1.1240154829579765e-08, 'subsample_freq': 1}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:44:28,483] Trial 66 finished with value: 15.209477009929333 and parameters: {'n_estimators': 426, 'max_depth': 9, 'learning_rate': 0.011338672147046312, 'num_leaves': 204, 'subsample': 0.8480741614516214, 'colsample_bytree': 0.68494745648603, 'min_child_samples': 47, 'reg_alpha': 0.09233134429035028, 'reg_lambda': 5.119474696777619e-08, 'subsample_freq': 1}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:44:36,921] Trial 67 finished with value: 14.41256108148421 and parameters: {'n_estimators': 388, 'max_depth': 8, 'learning_rate': 0.22711302506476475, 'num_leaves': 192, 'subsample': 0.8020542400960559, 'colsample_bytree': 0.7093409977020629, 'min_child_samples': 13, 'reg_alpha': 0.03050389422626071, 'reg_lambda': 1.1427246689094442e-07, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:44:42,847] Trial 68 finished with value: 11.37537720782082 and parameters: {'n_estimators': 281, 'max_depth': 9, 'learning_rate': 0.07699676627904423, 'num_leaves': 137, 'subsample': 0.8728262768333523, 'colsample_bytree': 0.7865807368296297, 'min_child_samples': 11, 'reg_alpha': 5.550866007325554, 'reg_lambda': 2.448598047984984e-07, 'subsample_freq': 2}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:44:56,249] Trial 69 finished with value: 10.949829167732581 and parameters: {'n_estimators': 457, 'max_depth': 10, 'learning_rate': 0.012708839573517712, 'num_leaves': 175, 'subsample': 0.702062686295974, 'colsample_bytree': 0.76013790627809, 'min_child_samples': 8, 'reg_alpha': 1.092416381108241, 'reg_lambda': 2.2337606988215997e-08, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:45:08,812] Trial 70 finished with value: 11.145428212817654 and parameters: {'n_estimators': 325, 'max_depth': 9, 'learning_rate': 0.019427153438945806, 'num_leaves': 212, 'subsample': 0.792176781906384, 'colsample_bytree': 0.7345708353795183, 'min_child_samples': 6, 'reg_alpha': 0.08318497757635523, 'reg_lambda': 7.679641295903719e-08, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:45:25,692] Trial 71 finished with value: 10.909527169519523 and parameters: {'n_estimators': 376, 'max_depth': 9, 'learning_rate': 0.01129547982834136, 'num_leaves': 160, 'subsample': 0.844758189771321, 'colsample_bytree': 0.6562333002036714, 'min_child_samples': 5, 'reg_alpha': 0.018450244399796745, 'reg_lambda': 4.977287222411754e-07, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:45:40,239] Trial 72 finished with value: 10.929616548394756 and parameters: {'n_estimators': 360, 'max_depth': 9, 'learning_rate': 0.01129564944828745, 'num_leaves': 121, 'subsample': 0.8221006526279581, 'colsample_bytree': 0.7066257823692386, 'min_child_samples': 6, 'reg_alpha': 0.02209129763535203, 'reg_lambda': 1.2665492784137261e-07, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:45:52,383] Trial 73 finished with value: 10.942778857279986 and parameters: {'n_estimators': 423, 'max_depth': 8, 'learning_rate': 0.013420210078815213, 'num_leaves': 160, 'subsample': 0.8485798241483637, 'colsample_bytree': 0.6612335781644599, 'min_child_samples': 10, 'reg_alpha': 0.0050036680890720425, 'reg_lambda': 2.2366561459814924e-06, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:46:06,705] Trial 74 finished with value: 11.044339481045675 and parameters: {'n_estimators': 380, 'max_depth': 10, 'learning_rate': 0.016217033090663472, 'num_leaves': 153, 'subsample': 0.7486793911630305, 'colsample_bytree': 0.5949668959622391, 'min_child_samples': 5, 'reg_alpha': 0.4930248235081468, 'reg_lambda': 8.304297684661915e-07, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:46:18,890] Trial 75 finished with value: 11.175930076073525 and parameters: {'n_estimators': 326, 'max_depth': 9, 'learning_rate': 0.01100310089731313, 'num_leaves': 138, 'subsample': 0.8822450353380957, 'colsample_bytree': 0.6257715430518201, 'min_child_samples': 8, 'reg_alpha': 0.01169762587167513, 'reg_lambda': 0.00011337592191938852, 'subsample_freq': 5}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:46:27,845] Trial 76 finished with value: 11.268238630332325 and parameters: {'n_estimators': 266, 'max_depth': 8, 'learning_rate': 0.012449731027924892, 'num_leaves': 103, 'subsample': 0.7979751307325287, 'colsample_bytree': 0.6849955142641626, 'min_child_samples': 6, 'reg_alpha': 0.2679224477810423, 'reg_lambda': 2.261760245775879e-06, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:46:31,873] Trial 77 finished with value: 15.362790065150017 and parameters: {'n_estimators': 474, 'max_depth': 10, 'learning_rate': 0.01607771349743749, 'num_leaves': 171, 'subsample': 0.5021039647552022, 'colsample_bytree': 0.6974233703543617, 'min_child_samples': 37, 'reg_alpha': 0.07997227761364259, 'reg_lambda': 1.3203798127074072e-05, 'subsample_freq': 7}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:46:42,669] Trial 78 finished with value: 11.065799107978979 and parameters: {'n_estimators': 409, 'max_depth': 9, 'learning_rate': 0.013914767868913639, 'num_leaves': 175, 'subsample': 0.8437821819742821, 'colsample_bytree': 0.7355167434611077, 'min_child_samples': 14, 'reg_alpha': 0.008291600734157027, 'reg_lambda': 3.3653834798700123e-07, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:46:57,167] Trial 79 finished with value: 10.966762820657271 and parameters: {'n_estimators': 444, 'max_depth': 9, 'learning_rate': 0.010784985645332945, 'num_leaves': 191, 'subsample': 0.8263029520496952, 'colsample_bytree': 0.6404120587578805, 'min_child_samples': 9, 'reg_alpha': 0.03442945615837789, 'reg_lambda': 5.2315613729465266e-08, 'subsample_freq': 3}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:47:06,919] Trial 80 finished with value: 11.238216003442135 and parameters: {'n_estimators': 498, 'max_depth': 6, 'learning_rate': 0.012151004725871488, 'num_leaves': 161, 'subsample': 0.7839945214162977, 'colsample_bytree': 0.7181221085543749, 'min_child_samples': 12, 'reg_alpha': 0.1980741268214121, 'reg_lambda': 1.4795628138409815e-07, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:47:28,196] Trial 81 finished with value: 10.974835345167445 and parameters: {'n_estimators': 556, 'max_depth': 9, 'learning_rate': 0.010986478082636308, 'num_leaves': 142, 'subsample': 0.732280582473168, 'colsample_bytree': 0.6558454747151813, 'min_child_samples': 5, 'reg_alpha': 0.06200557796221501, 'reg_lambda': 4.0495443162000463e-07, 'subsample_freq': 9}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:47:50,353] Trial 82 finished with value: 10.880278055022771 and parameters: {'n_estimators': 517, 'max_depth': 10, 'learning_rate': 0.010107994909031836, 'num_leaves': 153, 'subsample': 0.774506261595152, 'colsample_bytree': 0.6811326674363013, 'min_child_samples': 5, 'reg_alpha': 0.12581342609399038, 'reg_lambda': 2.3189775311651637e-08, 'subsample_freq': 8}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:48:04,882] Trial 83 finished with value: 10.941592996599402 and parameters: {'n_estimators': 381, 'max_depth': 10, 'learning_rate': 0.010107317142849155, 'num_leaves': 152, 'subsample': 0.8194633646198639, 'colsample_bytree': 0.6802477976959523, 'min_child_samples': 7, 'reg_alpha': 0.12341935698955929, 'reg_lambda': 1.863790072424016e-08, 'subsample_freq': 8}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:48:23,693] Trial 84 finished with value: 11.037990022837356 and parameters: {'n_estimators': 479, 'max_depth': 11, 'learning_rate': 0.013730672256090192, 'num_leaves': 113, 'subsample': 0.8013443853383533, 'colsample_bytree': 0.6961114940894183, 'min_child_samples': 6, 'reg_alpha': 0.37403279422030694, 'reg_lambda': 1.0101447670173888e-08, 'subsample_freq': 10}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:48:39,457] Trial 85 finished with value: 10.845760159142884 and parameters: {'n_estimators': 519, 'max_depth': 10, 'learning_rate': 0.01154753124133328, 'num_leaves': 165, 'subsample': 0.7570777838622584, 'colsample_bytree': 0.7685590444319003, 'min_child_samples': 8, 'reg_alpha': 1.2740621908768346, 'reg_lambda': 4.046188346979618e-08, 'subsample_freq': 8}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:49:07,386] Trial 86 finished with value: 11.292357510811074 and parameters: {'n_estimators': 589, 'max_depth': 10, 'learning_rate': 0.011658031800050895, 'num_leaves': 299, 'subsample': 0.7509327202369543, 'colsample_bytree': 0.7910857464446269, 'min_child_samples': 5, 'reg_alpha': 0.024318269218954677, 'reg_lambda': 3.385338460898235e-08, 'subsample_freq': 8}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:49:20,362] Trial 87 finished with value: 10.948789979337894 and parameters: {'n_estimators': 515, 'max_depth': 10, 'learning_rate': 0.012516973860761853, 'num_leaves': 198, 'subsample': 0.6038625636408697, 'colsample_bytree': 0.7743622075814751, 'min_child_samples': 10, 'reg_alpha': 0.5754583601137837, 'reg_lambda': 7.074442165431128e-08, 'subsample_freq': 7}. Best is trial 47 with value: 10.837537396989418.
# [I 2026-04-10 10:49:35,104] Trial 88 finished with value: 10.792707720547732 and parameters: {'n_estimators': 560, 'max_depth': 8, 'learning_rate': 0.010987135331927333, 'num_leaves': 175, 'subsample': 0.7843921499150339, 'colsample_bytree': 0.741236429681209, 'min_child_samples': 7, 'reg_alpha': 3.5369194939647897, 'reg_lambda': 2.3537349161129572e-08, 'subsample_freq': 9}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:49:50,433] Trial 89 finished with value: 11.020768470487347 and parameters: {'n_estimators': 624, 'max_depth': 7, 'learning_rate': 0.017847224520972628, 'num_leaves': 213, 'subsample': 0.7820518430389272, 'colsample_bytree': 0.7694648976557191, 'min_child_samples': 7, 'reg_alpha': 3.8834005070829796, 'reg_lambda': 2.2174575859441926e-08, 'subsample_freq': 8}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:50:06,019] Trial 90 finished with value: 10.897369831967636 and parameters: {'n_estimators': 690, 'max_depth': 8, 'learning_rate': 0.010053464178618058, 'num_leaves': 176, 'subsample': 0.7626086557625475, 'colsample_bytree': 0.8297670495609104, 'min_child_samples': 9, 'reg_alpha': 6.547524889143672, 'reg_lambda': 4.3563336201293e-08, 'subsample_freq': 9}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:50:23,154] Trial 91 finished with value: 10.835899302189459 and parameters: {'n_estimators': 790, 'max_depth': 8, 'learning_rate': 0.010196699322423319, 'num_leaves': 175, 'subsample': 0.7657400776506101, 'colsample_bytree': 0.8466486885161528, 'min_child_samples': 9, 'reg_alpha': 8.146931346499786, 'reg_lambda': 4.427583521782728e-08, 'subsample_freq': 9}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:50:42,942] Trial 92 finished with value: 11.124737641238056 and parameters: {'n_estimators': 828, 'max_depth': 8, 'learning_rate': 0.01447624928130876, 'num_leaves': 183, 'subsample': 0.7710306675134067, 'colsample_bytree': 0.7997269167591774, 'min_child_samples': 11, 'reg_alpha': 2.263086120701125, 'reg_lambda': 1.7657194107696156e-08, 'subsample_freq': 9}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:50:55,372] Trial 93 finished with value: 10.962617468851537 and parameters: {'n_estimators': 564, 'max_depth': 8, 'learning_rate': 0.010847958418921133, 'num_leaves': 135, 'subsample': 0.7289019015381816, 'colsample_bytree': 0.9983998073409955, 'min_child_samples': 8, 'reg_alpha': 9.034967519518567, 'reg_lambda': 1.0525813418533253e-07, 'subsample_freq': 7}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:51:19,822] Trial 94 finished with value: 11.485542483873107 and parameters: {'n_estimators': 917, 'max_depth': 7, 'learning_rate': 0.012479070993619794, 'num_leaves': 167, 'subsample': 0.7495873367818007, 'colsample_bytree': 0.8884038260940466, 'min_child_samples': 6, 'reg_alpha': 1.4163902731954952, 'reg_lambda': 3.2784843051777726e-08, 'subsample_freq': 8}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:51:42,806] Trial 95 finished with value: 11.125622428237296 and parameters: {'n_estimators': 962, 'max_depth': 9, 'learning_rate': 0.015573502635627741, 'num_leaves': 188, 'subsample': 0.7883837476702155, 'colsample_bytree': 0.7624638878104669, 'min_child_samples': 10, 'reg_alpha': 4.450413357006327, 'reg_lambda': 2.0775626131734504e-07, 'subsample_freq': 9}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:52:11,483] Trial 96 finished with value: 11.172420814831463 and parameters: {'n_estimators': 864, 'max_depth': 11, 'learning_rate': 0.010700479661120721, 'num_leaves': 151, 'subsample': 0.6994801233488661, 'colsample_bytree': 0.7398610576898553, 'min_child_samples': 7, 'reg_alpha': 0.676299632312341, 'reg_lambda': 8.567965473946392e-08, 'subsample_freq': 9}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:52:23,554] Trial 97 finished with value: 11.735238762925828 and parameters: {'n_estimators': 526, 'max_depth': 8, 'learning_rate': 0.03829137857072829, 'num_leaves': 198, 'subsample': 0.7211065635857057, 'colsample_bytree': 0.8550066430807367, 'min_child_samples': 12, 'reg_alpha': 2.17916033537505, 'reg_lambda': 5.3411507267764076e-08, 'subsample_freq': 9}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:52:38,483] Trial 98 finished with value: 13.710343911243292 and parameters: {'n_estimators': 542, 'max_depth': 10, 'learning_rate': 0.10377256606736962, 'num_leaves': 165, 'subsample': 0.8131302088539368, 'colsample_bytree': 0.9419211551342757, 'min_child_samples': 13, 'reg_alpha': 0.27309654523141735, 'reg_lambda': 2.5090732861810178e-08, 'subsample_freq': 8}. Best is trial 88 with value: 10.792707720547732.
# [I 2026-04-10 10:52:54,765] Trial 99 finished with value: 10.938987488139448 and parameters: {'n_estimators': 492, 'max_depth': 9, 'learning_rate': 0.010010821112594617, 'num_leaves': 174, 'subsample': 0.7384675029835128, 'colsample_bytree': 0.855411303951521, 'min_child_samples': 9, 'reg_alpha': 0.0001472824860471723, 'reg_lambda': 1.1383349195219396e-08, 'subsample_freq': 9}. Best is trial 88 with value: 10.792707720547732.
#
# 最佳超参数: {'n_estimators': 560, 'max_depth': 8, 'learning_rate': 0.010987135331927333, 'num_leaves': 175, 'subsample': 0.7843921499150339, 'colsample_bytree': 0.741236429681209, 'min_child_samples': 7, 'reg_alpha': 3.5369194939647897, 'reg_lambda': 2.3537349161129572e-08, 'subsample_freq': 9}
# 最佳交叉验证MSE: 10.7927
#
# ==================================================
# 模型性能评估
# ==================================================
# 指标              训练集             测试集             差异(%)
# --------------------------------------------------
# MSE             4.4966          47.3466         952.94
# RMSE            2.1205          6.8809          -
# MAE             1.4028          4.4956          -
# R²              0.9395          0.5380          40.15
# ==================================================
# 模型已保存到: LightGBM_regression_model.pkl
#
# 优化完成！
#
# 最佳参数数量: 11
# 训练集R²: 0.9395
# 测试集R²: 0.5380
