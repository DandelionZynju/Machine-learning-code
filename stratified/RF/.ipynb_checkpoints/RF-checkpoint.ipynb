# %%
import os
import sys
import random
import functools
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import optuna
from optuna.samplers import TPESampler
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import RepeatedKFold
import warnings
warnings.filterwarnings('ignore')

os.environ['PYTHONHASHSEED'] = '3407'
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"

SEED = 3407
random.seed(SEED)
np.random.seed(SEED)

def set_all_random_seeds(seed=3407):
    np.random.seed(seed)
    random.seed(seed)
    print(f"已设置随机种子为: {seed}")

def print_data_shapes(X_train, y_train, X_test, y_test):
    print(f"训练集形状: {X_train.shape}")
    print(f"测试集形状: {X_test.shape}")

def objective(trial, X_train, y_train, cv_folds, seed=3407):
  
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'random_state': seed,
        'n_jobs': 1,
        'verbose': 0
    }
   
    model = RandomForestRegressor(**params)
    
    rkf = RepeatedKFold(n_splits=cv_folds, n_repeats=5, random_state=seed)
    cv_scores = cross_val_score(
        model, X_train, y_train,
        cv=rkf, scoring='neg_mean_squared_error',
        n_jobs=1
    )
    mse_scores = -cv_scores
    avg_mse = np.mean(mse_scores)
    mse_std = np.std(mse_scores)
    stability_penalty = 0.1 * mse_std / avg_mse if avg_mse > 0 else 0
    return avg_mse + stability_penalty

def optimize_hyperparameters(X_train, y_train, n_trials=100, cv_folds=10, seed=3407):
    print("开始 Optuna 超参数优化（随机森林）...")

    sampler = TPESampler(
        seed=seed,
        n_startup_trials=10,
        group=False,
        warn_independent_sampling=False
    )

    study = optuna.create_study(
        direction='minimize',
        study_name=f'random_forest_regression_seed{seed}',
        storage=None,
        load_if_exists=False,
        sampler=sampler,
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=10)
    )
    
    objective_partial = functools.partial(
        objective,
        X_train=X_train,
        y_train=y_train,
        cv_folds=cv_folds,
        seed=seed
    )
    
    study.optimize(objective_partial, n_trials=n_trials, n_jobs=1, show_progress_bar=True)
    
    best_params = study.best_params
    print(f"\n最佳超参数: {best_params}")
    print(f"最佳交叉验证 MSE: {study.best_value:.4f}")
    
    best_params['random_state'] = seed
    return best_params, study

def train_best_model(X_train, y_train, best_params, seed=3407):
   
    final_params = best_params.copy()
    final_params.update({
        'random_state': seed,
        'n_jobs': 1,
        'verbose': 0
    })
    model = RandomForestRegressor(**final_params)
    model.fit(X_train, y_train)
    return model, (X_train, y_train)

def evaluate_model(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)
    train_mae = mean_absolute_error(y_train, y_train_pred)
    test_mae = mean_absolute_error(y_test, y_test_pred)
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    
    mse_diff = abs(train_mse - test_mse) / train_mse * 100 if train_mse > 0 else 0
    r2_diff = abs(train_r2 - test_r2) * 100
    
    print("\n" + "="*50)
    print("模型性能评估")
    print("="*50)
    print(f"{'指标':<15} {'训练集':<15} {'测试集':<15} {'差异(%)':<10}")
    print("-"*50)
    print(f"{'MSE':<15} {train_mse:<15.4f} {test_mse:<15.4f} {mse_diff:<10.2f}")
    print(f"{'RMSE':<15} {np.sqrt(train_mse):<15.4f} {np.sqrt(test_mse):<15.4f} {'-':<10}")
    print(f"{'MAE':<15} {train_mae:<15.4f} {test_mae:<15.4f} {'-':<10}")
    print(f"{'R²':<15} {train_r2:<15.4f} {test_r2:<15.4f} {r2_diff:<10.2f}")
    print("="*50)
    
    metrics_dict = {
        'train_mse': train_mse, 'test_mse': test_mse,
        'train_mae': train_mae, 'test_mae': test_mae,
        'train_r2': train_r2, 'test_r2': test_r2,
        'mse_diff_percent': mse_diff, 'r2_diff_percent': r2_diff
    }
    predictions = {'y_train_pred': y_train_pred, 'y_test_pred': y_test_pred}
    return metrics_dict, predictions

def save_model(model, filepath='best_random_forest_model.pkl'):
    import joblib
    joblib.dump(model, filepath)
    print(f"模型已保存到: {filepath}")

def random_forest_optimization_pipeline(X_train, y_train, X_test, y_test, n_trials=100, cv_folds=5, seed=3407):
    set_all_random_seeds(seed)
    print_data_shapes(X_train, y_train, X_test, y_test)
    
    best_params, study = optimize_hyperparameters(
        X_train, y_train, n_trials, cv_folds, seed
    )
    model, train_data = train_best_model(X_train, y_train, best_params, seed)
    metrics, predictions = evaluate_model(model, X_train, y_train, X_test, y_test)
    save_model(model, 'RandomForest_regression_model.pkl')
    print("\n优化完成！")
    return model, best_params, metrics, study, predictions, train_data

def main():
    SEED = 36
    
    X_train = pd.read_csv("data_train_x.csv")
    X_test  = pd.read_csv("data_test_x.csv")
    y_train = pd.read_csv("data_train_y.csv")
    y_test  = pd.read_csv("data_test_y.csv")
    
    if len(y_train.shape) > 1 and y_train.shape[1] == 1:
        y_train = y_train.iloc[:, 0]
    if len(y_test.shape) > 1 and y_test.shape[1] == 1:
        y_test = y_test.iloc[:, 0]
    
    model, best_params, metrics, study, predictions, train_data = random_forest_optimization_pipeline(
        X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test,
        n_trials=100,
        cv_folds=10,
        seed=SEED
    )
    
    print(f"\n最佳参数数量: {len(best_params)}")
    print(f"训练集 R²: {metrics['train_r2']:.4f}")
    print(f"测试集 R²: {metrics['test_r2']:.4f}")
    
    results = {
        'model': model, 'best_params': best_params, 'metrics': metrics,
        'study': study, 'predictions': predictions, 'train_data': train_data
    }
    return results

if __name__ == "__main__":
    results = main()
# Out:
# [I 2026-04-09 09:17:13,930] A new study created in memory with name: random_forest_regression_seed36
# 已设置随机种子为: 36
# 训练集形状: (918, 30)
# 测试集形状: (234, 30)
# 开始 Optuna 超参数优化（随机森林）...
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-04-09 09:17:31,448] Trial 0 finished with value: 13.018594262870758 and parameters: {'n_estimators': 378, 'max_depth': 13, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 13.018594262870758.
# [I 2026-04-09 09:17:34,269] Trial 1 finished with value: 14.49646036157553 and parameters: {'n_estimators': 64, 'max_depth': 20, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 13.018594262870758.
# [I 2026-04-09 09:17:47,618] Trial 2 finished with value: 14.82933090030093 and parameters: {'n_estimators': 254, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 13.018594262870758.
# [I 2026-04-09 09:17:53,699] Trial 3 finished with value: 17.04529720780028 and parameters: {'n_estimators': 147, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 13.018594262870758.
# [I 2026-04-09 09:18:54,153] Trial 4 finished with value: 12.476024940490609 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 4 with value: 12.476024940490609.
# [I 2026-04-09 09:19:04,667] Trial 5 finished with value: 15.649619454969175 and parameters: {'n_estimators': 208, 'max_depth': 11, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True}. Best is trial 4 with value: 12.476024940490609.
# [I 2026-04-09 09:19:09,660] Trial 6 finished with value: 28.089326644239975 and parameters: {'n_estimators': 142, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 4 with value: 12.476024940490609.
# [I 2026-04-09 09:19:16,476] Trial 7 finished with value: 22.055687995110674 and parameters: {'n_estimators': 140, 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 4 with value: 12.476024940490609.
# [I 2026-04-09 09:19:32,412] Trial 8 finished with value: 13.308123864100196 and parameters: {'n_estimators': 349, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False}. Best is trial 4 with value: 12.476024940490609.
# [I 2026-04-09 09:19:43,096] Trial 9 finished with value: 18.26679334061035 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 4 with value: 12.476024940490609.
# [I 2026-04-09 09:21:09,944] Trial 10 finished with value: 11.17014959802041 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 10 with value: 11.17014959802041.
# [I 2026-04-09 09:22:38,533] Trial 11 finished with value: 11.17014959802041 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 10 with value: 11.17014959802041.
# [I 2026-04-09 09:24:01,152] Trial 12 finished with value: 11.139302488601935 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 12 with value: 11.139302488601935.
# [I 2026-04-09 09:25:12,220] Trial 13 finished with value: 10.973914610146434 and parameters: {'n_estimators': 417, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 13 with value: 10.973914610146434.
# [I 2026-04-09 09:26:10,664] Trial 14 finished with value: 11.617217170576614 and parameters: {'n_estimators': 404, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 13 with value: 10.973914610146434.
# [I 2026-04-09 09:27:09,199] Trial 15 finished with value: 11.726879432621299 and parameters: {'n_estimators': 431, 'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 13 with value: 10.973914610146434.
# [I 2026-04-09 09:27:55,904] Trial 16 finished with value: 11.202223724776104 and parameters: {'n_estimators': 312, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 13 with value: 10.973914610146434.
# [I 2026-04-09 09:28:50,421] Trial 17 finished with value: 12.273100529397253 and parameters: {'n_estimators': 455, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True}. Best is trial 13 with value: 10.973914610146434.
# [I 2026-04-09 09:29:35,519] Trial 18 finished with value: 11.82660853257573 and parameters: {'n_estimators': 340, 'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 13 with value: 10.973914610146434.
# [I 2026-04-09 09:30:33,769] Trial 19 finished with value: 11.881441400891434 and parameters: {'n_estimators': 446, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 13 with value: 10.973914610146434.
# [I 2026-04-09 09:31:21,724] Trial 20 finished with value: 10.864406323022342 and parameters: {'n_estimators': 286, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:32:06,407] Trial 21 finished with value: 10.942957065615008 and parameters: {'n_estimators': 295, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:32:46,654] Trial 22 finished with value: 10.912299181430033 and parameters: {'n_estimators': 254, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:33:30,281] Trial 23 finished with value: 10.902436022520014 and parameters: {'n_estimators': 275, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:34:03,613] Trial 24 finished with value: 11.633331346391616 and parameters: {'n_estimators': 254, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:34:16,157] Trial 25 finished with value: 11.46014018962886 and parameters: {'n_estimators': 207, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:35:02,502] Trial 26 finished with value: 13.554869623512426 and parameters: {'n_estimators': 267, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:35:34,067] Trial 27 finished with value: 11.434988262294109 and parameters: {'n_estimators': 235, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:36:18,940] Trial 28 finished with value: 11.20160968795446 and parameters: {'n_estimators': 316, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:36:36,458] Trial 29 finished with value: 11.692583515171455 and parameters: {'n_estimators': 358, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:36:57,121] Trial 30 finished with value: 12.056595355220864 and parameters: {'n_estimators': 173, 'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:37:42,868] Trial 31 finished with value: 10.896661631192055 and parameters: {'n_estimators': 292, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:38:30,113] Trial 32 finished with value: 10.936000740353021 and parameters: {'n_estimators': 302, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:39:09,819] Trial 33 finished with value: 11.341445247298076 and parameters: {'n_estimators': 282, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:39:50,763] Trial 34 finished with value: 13.525467305503685 and parameters: {'n_estimators': 235, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:40:01,184] Trial 35 finished with value: 12.348011417643866 and parameters: {'n_estimators': 90, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:40:21,832] Trial 36 finished with value: 13.042856353459698 and parameters: {'n_estimators': 377, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:40:38,493] Trial 37 finished with value: 15.203780806697848 and parameters: {'n_estimators': 329, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:41:24,901] Trial 38 finished with value: 15.009634941483156 and parameters: {'n_estimators': 240, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:41:39,591] Trial 39 finished with value: 15.79947622651498 and parameters: {'n_estimators': 284, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:41:48,919] Trial 40 finished with value: 14.697355579150656 and parameters: {'n_estimators': 178, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:42:36,244] Trial 41 finished with value: 10.936000740353021 and parameters: {'n_estimators': 302, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:43:17,336] Trial 42 finished with value: 11.005431862120057 and parameters: {'n_estimators': 267, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:43:49,844] Trial 43 finished with value: 10.992658926438537 and parameters: {'n_estimators': 219, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:44:41,568] Trial 44 finished with value: 11.230444572561675 and parameters: {'n_estimators': 367, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:45:01,167] Trial 45 finished with value: 11.483837812515306 and parameters: {'n_estimators': 326, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:45:44,154] Trial 46 finished with value: 13.542210284797262 and parameters: {'n_estimators': 249, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:46:03,899] Trial 47 finished with value: 23.14464574838215 and parameters: {'n_estimators': 278, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:46:38,955] Trial 48 finished with value: 12.269573849286628 and parameters: {'n_estimators': 300, 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:47:09,647] Trial 49 finished with value: 11.02738442228126 and parameters: {'n_estimators': 183, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:47:29,395] Trial 50 finished with value: 16.93614919215106 and parameters: {'n_estimators': 392, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:48:17,751] Trial 51 finished with value: 10.927882838419524 and parameters: {'n_estimators': 308, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:49:08,017] Trial 52 finished with value: 11.001529300830228 and parameters: {'n_estimators': 342, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 20 with value: 10.864406323022342.
# [I 2026-04-09 09:50:01,632] Trial 53 finished with value: 10.856086558718403 and parameters: {'n_estimators': 321, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 53 with value: 10.856086558718403.
# [I 2026-04-09 09:50:43,384] Trial 54 finished with value: 10.850166588395174 and parameters: {'n_estimators': 262, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 54 with value: 10.850166588395174.
# [I 2026-04-09 09:51:24,533] Trial 55 finished with value: 10.857447273167445 and parameters: {'n_estimators': 258, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 54 with value: 10.850166588395174.
# [I 2026-04-09 09:51:55,874] Trial 56 finished with value: 11.22273943022564 and parameters: {'n_estimators': 223, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 54 with value: 10.850166588395174.
# [I 2026-04-09 09:52:41,499] Trial 57 finished with value: 10.845964134294146 and parameters: {'n_estimators': 268, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 57 with value: 10.845964134294146.
# [I 2026-04-09 09:53:27,450] Trial 58 finished with value: 10.850166588395174 and parameters: {'n_estimators': 262, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 57 with value: 10.845964134294146.
# [I 2026-04-09 09:53:42,286] Trial 59 finished with value: 11.27127357806191 and parameters: {'n_estimators': 256, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}. Best is trial 57 with value: 10.845964134294146.
# [I 2026-04-09 09:54:12,354] Trial 60 finished with value: 11.551505402215433 and parameters: {'n_estimators': 219, 'max_depth': 17, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 57 with value: 10.845964134294146.
# [I 2026-04-09 09:54:54,647] Trial 61 finished with value: 10.849249788603576 and parameters: {'n_estimators': 263, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 57 with value: 10.845964134294146.
# [I 2026-04-09 09:55:36,290] Trial 62 finished with value: 10.971195939097829 and parameters: {'n_estimators': 269, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 57 with value: 10.845964134294146.
# [I 2026-04-09 09:56:08,770] Trial 63 finished with value: 10.860359418817405 and parameters: {'n_estimators': 192, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 57 with value: 10.845964134294146.
# [I 2026-04-09 09:56:32,786] Trial 64 finished with value: 10.909126756826405 and parameters: {'n_estimators': 152, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 57 with value: 10.845964134294146.
# [I 2026-04-09 09:56:50,386] Trial 65 finished with value: 10.844629906317541 and parameters: {'n_estimators': 109, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 09:57:07,798] Trial 66 finished with value: 12.783272482383177 and parameters: {'n_estimators': 160, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 09:57:26,814] Trial 67 finished with value: 10.977250980952574 and parameters: {'n_estimators': 127, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 09:57:37,959] Trial 68 finished with value: 11.132039061060102 and parameters: {'n_estimators': 76, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 09:57:55,395] Trial 69 finished with value: 10.98889245656813 and parameters: {'n_estimators': 116, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 09:59:01,980] Trial 70 finished with value: 11.197158260009592 and parameters: {'n_estimators': 470, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 09:59:19,306] Trial 71 finished with value: 10.961842030622066 and parameters: {'n_estimators': 95, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 09:59:50,685] Trial 72 finished with value: 10.855243484754137 and parameters: {'n_estimators': 193, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 09:59:59,762] Trial 73 finished with value: 10.89252888237927 and parameters: {'n_estimators': 54, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:00:51,697] Trial 74 finished with value: 10.850985742695098 and parameters: {'n_estimators': 323, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:01:42,460] Trial 75 finished with value: 11.03362083411833 and parameters: {'n_estimators': 349, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:02:08,917] Trial 76 finished with value: 11.837721777138613 and parameters: {'n_estimators': 325, 'max_depth': 19, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:02:21,710] Trial 77 finished with value: 11.280817519998454 and parameters: {'n_estimators': 229, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:02:47,675] Trial 78 finished with value: 11.885924546836247 and parameters: {'n_estimators': 205, 'max_depth': 19, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:03:22,430] Trial 79 finished with value: 11.218715878363557 and parameters: {'n_estimators': 244, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:04:07,093] Trial 80 finished with value: 10.92384798688497 and parameters: {'n_estimators': 291, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:04:50,380] Trial 81 finished with value: 10.863842212457829 and parameters: {'n_estimators': 258, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 65 with value: 10.844629906317541.
# [I 2026-04-09 10:05:32,775] Trial 82 finished with value: 10.844351518472882 and parameters: {'n_estimators': 265, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:06:26,249] Trial 83 finished with value: 10.85017344816995 and parameters: {'n_estimators': 334, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:07:07,793] Trial 84 finished with value: 10.92544454396335 and parameters: {'n_estimators': 270, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:07:57,431] Trial 85 finished with value: 10.97104228789979 and parameters: {'n_estimators': 332, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:08:52,831] Trial 86 finished with value: 10.905252087756379 and parameters: {'n_estimators': 360, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:09:36,764] Trial 87 finished with value: 10.938921361418668 and parameters: {'n_estimators': 287, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:10:13,422] Trial 88 finished with value: 10.897581231016423 and parameters: {'n_estimators': 238, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:10:28,228] Trial 89 finished with value: 13.239851735908543 and parameters: {'n_estimators': 314, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:10:58,118] Trial 90 finished with value: 14.039903130140456 and parameters: {'n_estimators': 278, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:11:50,733] Trial 91 finished with value: 10.849674430817783 and parameters: {'n_estimators': 314, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:12:44,902] Trial 92 finished with value: 10.876946046143289 and parameters: {'n_estimators': 340, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:13:36,386] Trial 93 finished with value: 10.844692157858347 and parameters: {'n_estimators': 306, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:14:27,512] Trial 94 finished with value: 10.846828447737302 and parameters: {'n_estimators': 303, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:14:46,238] Trial 95 finished with value: 11.31372655169368 and parameters: {'n_estimators': 296, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:15:47,448] Trial 96 finished with value: 11.032767715581368 and parameters: {'n_estimators': 308, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:16:48,838] Trial 97 finished with value: 10.8937398191331 and parameters: {'n_estimators': 385, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:17:32,696] Trial 98 finished with value: 10.862632179380642 and parameters: {'n_estimators': 261, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
# [I 2026-04-09 10:18:11,168] Trial 99 finished with value: 11.913325767197577 and parameters: {'n_estimators': 309, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 82 with value: 10.844351518472882.
#
# 最佳超参数: {'n_estimators': 265, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}
# 最佳交叉验证 MSE: 10.8444
#
# ==================================================
# 模型性能评估
# ==================================================
# 指标              训练集             测试集             差异(%)
# --------------------------------------------------
# MSE             4.0195          44.6036         1009.68
# RMSE            2.0049          6.6786          -
# MAE             1.2597          4.2409          -
# R²              0.9459          0.5648          38.12
# ==================================================
# 模型已保存到: RandomForest_regression_model.pkl
#
# 优化完成！
#
# 最佳参数数量: 7
# 训练集 R²: 0.9459
# 测试集 R²: 0.5648
